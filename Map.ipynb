# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan_.csv')
df
# Out:
#      Station  Longitude  Latitude  Elevation
# 0      56038      98.10     32.98     4200.0
# 1      56079     102.97     33.58     3441.4
# 2      56097     104.25     33.27     1436.5
# 3      56144      98.58     31.80     3184.0
# 4      56146     100.00     31.62     3393.5
# ..       ...        ...       ...        ...
# 151    57600     105.07     28.72      263.0
# 152    57603     105.83     28.82      283.4
# 153    57604     105.38     28.78      368.8
# 154    57605     105.82     28.03      537.7
# 155    57608     105.43     28.17      377.5
#
# [156 rows x 4 columns]

# %%
geometry = [Point(xy) for xy in zip(df["Longitude"], df["Latitude"])]
geometry[:155]

# %%
geo_df = gpd.GeoDataFrame(df,
                         geometry = geometry)
geo_df.head()
# Out:
#    Station  Longitude  Latitude  Elevation                    geometry
# 0    56038      98.10     32.98     4200.0   POINT (98.10000 32.98000)
# 1    56079     102.97     33.58     3441.4  POINT (102.97000 33.58000)
# 2    56097     104.25     33.27     1436.5  POINT (104.25000 33.27000)
# 3    56144      98.58     31.80     3184.0   POINT (98.58000 31.80000)
# 4    56146     100.00     31.62     3393.5  POINT (100.00000 31.62000)

# %%
Sichuan = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan_.csv')
lat = Sichuan["Latitude"]
lon = Sichuan["Longitude"]
loni, lati = np.meshgrid(lon, lat)
plt.contour(loni,lati)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xticks(np.arange(90, 120, 20))
plt.yticks(np.arange(20, 50, 10))
plt.xlim(90, 120)
plt.ylim(20, 50)
# Out:
# <ipython-input-43-18ec4849292c>:5: UserWarning: No contour levels were found within the data range.
#   plt.contour(loni,lati)
# (20.0, 50.0)

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan_.csv')
df
plt.scatter(x=df["Longitude"], y=df["Latitude"])
plt.show()

# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan_.csv', delimiter=',', skiprows=0, low_memory=False)

geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
gdf = GeoDataFrame(df, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15);

# %%
import geopandas as gp
data = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan_.csv')
geo_data = gp.GeoDataFrame(data, geometry=gp.points_from_xy(data.Longitude, data.Latitude))
print(geo_data)
# Out:
#      Station  Longitude  Latitude  Elevation                    geometry
# 0      56038      98.10     32.98     4200.0   POINT (98.10000 32.98000)
# 1      56079     102.97     33.58     3441.4  POINT (102.97000 33.58000)
# 2      56097     104.25     33.27     1436.5  POINT (104.25000 33.27000)
# 3      56144      98.58     31.80     3184.0   POINT (98.58000 31.80000)
# 4      56146     100.00     31.62     3393.5  POINT (100.00000 31.62000)
# ..       ...        ...       ...        ...                         ...
# 151    57600     105.07     28.72      263.0  POINT (105.07000 28.72000)
# 152    57603     105.83     28.82      283.4  POINT (105.83000 28.82000)
# 153    57604     105.38     28.78      368.8  POINT (105.38000 28.78000)
# 154    57605     105.82     28.03      537.7  POINT (105.82000 28.03000)
# 155    57608     105.43     28.17      377.5  POINT (105.43000 28.17000)
#
# [156 rows x 5 columns]

# %%
import geopandas as gp
data = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan_.csv')
geo_data = gp.GeoDataFrame(data, geometry=gp.points_from_xy(data.Longitude, data.Latitude))
print(geo_data)

def geo_china(df, size_column='size', title='map'):
    china_geod = gp.GeoDataFrame.from_file('/Users/annadugoul/Documents/SCData/yk817wg5569.shp')
    print(china_geod.head(5), china_geod.columns)
    ax = china_geod.plot(color='white', edgecolor='black')
    df.plot(ax=ax, color='red', markersize=df[size_column], alpha=0.5)
    ax.set_axis_off()
    plt.show()
# Out:
#      Station  Longitude  Latitude  Elevation                    geometry
# 0      56038      98.10     32.98     4200.0   POINT (98.10000 32.98000)
# 1      56079     102.97     33.58     3441.4  POINT (102.97000 33.58000)
# 2      56097     104.25     33.27     1436.5  POINT (104.25000 33.27000)
# 3      56144      98.58     31.80     3184.0   POINT (98.58000 31.80000)
# 4      56146     100.00     31.62     3393.5  POINT (100.00000 31.62000)
# ..       ...        ...       ...        ...                         ...
# 151    57600     105.07     28.72      263.0  POINT (105.07000 28.72000)
# 152    57603     105.83     28.82      283.4  POINT (105.83000 28.82000)
# 153    57604     105.38     28.78      368.8  POINT (105.38000 28.78000)
# 154    57605     105.82     28.03      537.7  POINT (105.82000 28.03000)
# 155    57608     105.43     28.17      377.5  POINT (105.43000 28.17000)
#
# [156 rows x 5 columns]

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan_.csv')
gdf = geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
ax = world[world.continent == 'Asia'].plot(
    color='white', edgecolor='black')
gdf.plot(ax=ax, color='red')
plt.show()

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
fp = '/Users/annadugoul/Documents/SCData/shp2/chn_admbnda_adm0_ocha_2020.shp'
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan.csv')
map_df = gpd.read_file(fp)
map_df.head()
map_df.plot()

import matplotlib.pyplot as plt
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan.csv')
df
plt.scatter(x=df["Longitude"], y=df["Latitude"], color='red', s=2)
plt.show()

# %%
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan_.csv')
df
plt.scatter(x=df["Longitude"], y=df["Latitude"])
plt.show()

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
fp = '/Users/annadugoul/Documents/SCData/shp2/chn_admbnda_adm1_ocha_2020.shp'
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan.csv')
map_df = gpd.read_file(fp)
map_df.plot()
df
plt.scatter(x=df["Longitude"], y=df["Latitude"], color='red', s=1)
plt.show()

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
fp = '/Users/annadugoul/Documents/SCData/shp2/chn_admbndl_ALL_ocha_2020.shp'
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan.csv')
map_df = gpd.read_file(fp)
map_df.head()
map_df.plot()

import matplotlib.pyplot as plt
df = pd.read_csv('/Users/annadugoul/Documents/SCData/Sta_SiChuan.csv')
df
plt.scatter(x=df["Longitude"], y=df["Latitude"], color='red', s=2)
plt.show()
